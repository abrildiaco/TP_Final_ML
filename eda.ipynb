# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
from src.eda import explore_features

# %% [markdown]
# # Exploratory Data Analysis

# %%
dataset = pd.read_csv("data/pf_suvs.csv")

# %%
for column in dataset.columns:
    print(column)
# Out:
# Unnamed: 0
# Marca
# Modelo
# Año
# Versión
# Color
# Tipo de combustible
# Puertas
# Transmisión
# Motor
# Tipo de carrocería
# Con cámara de retroceso
# Kilómetros
# Título
# Precio
# Moneda
# Descripción
# Tipo de vendedor

# %%
TARGET = "Precio"

X = dataset.drop(columns = [TARGET])
y = dataset[TARGET]

# %% [markdown]
# ### Features Analysis

# %%
# Explore Dataset Features
feature_summary = explore_features(X)
display(feature_summary)
# Out:
#                     feature    dtype  missing  missing_%  unique  \
# 0                     Marca      str        0       0.00      47
# 1                    Modelo      str        0       0.00     137
# 2                       Año  float64        0       0.00      40
# 3                   Versión      str        0       0.00    2072
# 4                     Color      str      389       2.13      70
# 5       Tipo de combustible      str        0       0.00       8
# 6                   Puertas  float64        0       0.00       7
# 7               Transmisión      str       15       0.08       4
# 8                     Motor      str       38       0.21     271
# 9        Tipo de carrocería      str        0       0.00       1
# 10  Con cámara de retroceso      str    13563      74.30       2
# 11               Kilómetros      str        0       0.00    2175
# 12                   Título      str        0       0.00    2220
# 13                   Moneda      str        0       0.00       2
# 14              Descripción      str        0       0.00   12142
# 15         Tipo de vendedor      str        0       0.00       3
#
#                                         most_frequent     min  median  \
# 0                                                Ford     NaN     NaN
# 1                                            Ecosport     NaN     NaN
# 2                                              2025.0  1981.0  2019.0
# 3                                   1.6 Exclusive Cvt     NaN     NaN
# 4                                                Gris     NaN     NaN
# 5                                               Nafta     NaN     NaN
# 6                                                 5.0     2.0     5.0
# 7                                          Automática     NaN     NaN
# 8                                                 1.6     NaN     NaN
# 9                                                 SUV     NaN     NaN
# 10                                                 Sí     NaN     NaN
# 11                                                0.0     NaN     NaN
# 12                     Nissan Kicks 1.6 Exclusive Cvt     NaN     NaN
# 13                                                  $     NaN     NaN
# 14  El vendedor no incluyó una descripción del pro...     NaN     NaN
# 15                                      concesionaria     NaN     NaN
#
#            mean       max
# 0           NaN       NaN
# 1           NaN       NaN
# 2   2042.796209  436694.0
# 3           NaN       NaN
# 4           NaN       NaN
# 5           NaN       NaN
# 6     18.167306   60252.0
# 7           NaN       NaN
# 8           NaN       NaN
# 9           NaN       NaN
# 10          NaN       NaN
# 11          NaN       NaN
# 12          NaN       NaN
# 13          NaN       NaN
# 14          NaN       NaN
# 15          NaN       NaN
