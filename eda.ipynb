# %% [markdown]
# <h3 style="background-color: #343a40; color: #ffffff; display: inline-block; padding: 6px 10px; border-radius: 6px;">
# Preprocesamiento de las features
# </h3>

# %% [markdown]
# <div style="
#     text-align: center;
#     background-color: rgba(0, 0, 0, 0.3);
#     color: white;
#     padding: 10px;
#     border-radius: 8px;
#     font-weight: bold;
# ">
# Limpieza y validación de la variable precio
# </div>

# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import src.eda_utils as eda

# %%
dataset = pd.read_csv("data/pf_suvs.csv")

# %% [markdown]
# <h1 style="
#     background-color: #d0ebff;
#     color: #1a1a1a;
#     display: inline-block;
#     padding: 10px 18px;
#     border-radius: 10px;
#     font-size: 32px;
# ">
# Exploratory Data Analysis
# </h1>

# %%
for column in dataset.columns:
    print(column)
# Out:
# Unnamed: 0
# Marca
# Modelo
# Año
# Versión
# Color
# Tipo de combustible
# Puertas
# Transmisión
# Motor
# Tipo de carrocería
# Con cámara de retroceso
# Kilómetros
# Título
# Precio
# Moneda
# Descripción
# Tipo de vendedor

# %%
TARGET = "Precio"

X = dataset.drop(columns = [TARGET])
y = dataset[TARGET]

# %%
pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", 120)
pd.set_option("display.width", 180)

# %% [markdown]
# <h3 style="background-color: #343a40; color: #ffffff; display: inline-block; padding: 6px 10px; border-radius: 6px;">
# Label Analysis
# </h3>

# %%
target_summary = eda.explore_target(y, currency=X["Moneda"])
display(target_summary)
# Out:
#   group  count  missing  missing_%       min          q1      median          mean          q3          max           std  zero_count
# 0   All  18254        0        0.0     111.0     31900.0  17200000.0  1.760162e+07  29950000.0  349500000.0  1.720810e+07           0
# 1     $  11158        0        0.0  119000.0  19000000.0  27320000.0  2.877461e+07  35900000.0  349500000.0  1.277861e+07           0
# 2   US$   7096        0        0.0     111.0     16000.0     24000.0  3.281019e+04     38900.0     610000.0  2.885445e+04           0

# %% [markdown]
# <h3 style="background-color: #343a40; color: #ffffff; display: inline-block; padding: 6px 10px; border-radius: 6px;">
# Feature Analysis
# </h3>

# %%
# Explore Dataset Features
feature_summary = eda.explore_features(X)

display(feature_summary["numeric"])
display(feature_summary["categorical"])
# Out:
#    feature    dtype  non_missing  missing  missing_%     min       max         mean  median          std      q1      q3  zero_count  outlier_count  outlier_%  unique  unique_%
# 0      Año  float64        18254        0        0.0  1981.0  436694.0  2042.796209  2019.0  3217.260996  2016.0  2024.0           0            260       1.42      40      0.22
# 1  Puertas  float64        18254        0        0.0     2.0   60252.0    18.167306     5.0   891.766121     5.0     5.0           0            523       2.87       7      0.04
#                     feature dtype                                                                                                       categories_preview  \
# 0                     Marca   str                                             Ford: 2161 | Jeep: 2050 | Volkswagen: 2037 | Chevrolet: 1750 | Renault: 1491
# 1                    Modelo   str                                                Ecosport: 1569 | Tracker: 1511 | 2008: 1144 | Duster: 1048 | Compass: 916
# 2                   Versión   str  1.6 Exclusive Cvt: 320 | 1.4 250 Tsi Comfortline: 261 | 1.4 250 Tsi Highline: 255 | 1.8 Ltz+ Awd At 140cv: 213 | 1.2...
# 3                     Color   str                                                    Gris: 5468 | Blanco: 4809 | Negro: 2825 | Plateado: 1427 | Azul: 1121
# 4       Tipo de combustible   str                                         Nafta: 16067 | Diésel: 1328 | Nafta/GNC: 451 | Híbrido/Nafta: 269 | Híbrido: 105
# 5               Transmisión   str                                        Automática: 12281 | Manual: 5834 | Automática secuencial: 123 | Semiautomática: 1
# 6                     Motor   str                                                                1.6: 4132 | 2.0: 3121 | 1.8: 1749 | 1.0: 1417 | 1.3: 1079
# 7        Tipo de carrocería   str                                                                                                               SUV: 18254
# 8   Con cámara de retroceso   str                                                                                                       Sí: 3731 | No: 960
# 9                Kilómetros   str                                                       0.0: 4237 | 0 km: 324 | 1000.0: 220 | 90000.0: 194 | 120000.0: 194
# 10                   Título   str  Nissan Kicks 1.6 Exclusive Cvt: 320 | Volkswagen Taos 1.4 250 Tsi Comfortline: 261 | Volkswagen Taos 1.4 250 Tsi Hig...
# 11                   Moneda   str                                                                                                     $: 11158 | US$: 7096
# 12              Descripción   str  El vendedor no incluyó una descripción del producto: 2260 | La tienda no incluyó una descripción del producto: 62 | ...
# 13         Tipo de vendedor   str                                                                    concesionaria: 8509 | particular: 5676 | tienda: 4069
#
#                                           most_frequent  most_frequent_count  most_frequent_%  \
# 0                                                  Ford                 2161            11.84
# 1                                              Ecosport                 1569             8.60
# 2                                     1.6 Exclusive Cvt                  320             1.75
# 3                                                  Gris                 5468            29.96
# 4                                                 Nafta                16067            88.02
# 5                                            Automática                12281            67.28
# 6                                                   1.6                 4132            22.64
# 7                                                   SUV                18254           100.00
# 8                                                    Sí                 3731            20.44
# 9                                                   0.0                 4237            23.21
# 10                       Nissan Kicks 1.6 Exclusive Cvt                  320             1.75
# 11                                                    $                11158            61.13
# 12  El vendedor no incluyó una descripción del producto                 2260            12.38
# 13                                        concesionaria                 8509            46.61
#
#                                                                                                      least_frequent_preview  rare_categories  missing  missing_%  non_missing  \
# 0                                                             Range Rover: 1 | Rrenault: 1 | Jetur: 1 | hiunday: 1 | Vol: 1                5        0       0.00        18254
# 1                                                             Tiggo 8 Pro: 2 | Clase GL: 2 | DS3: 2 | Mohave: 2 | F-PACE: 2                0        0       0.00        18254
# 2   2.0 Hse 4 At: 1 | 2.7 4WD V6: 1 | 2.0 GLC300 4MATIC COUPE AMG-LINE: 1 | 1.8 Awd Ltz At: 1 | Trendline 200 Tsi Automa...             1038        0       0.00        18254
# 3   GRIS SILVERSTONE: 1 | GRANITE CRYSTA BC: 1 | SKYSCRAPER GRAU METALLIC: 1 | BLANCO BANCHISA BICOLOR NEGRO: 1 | GRIS P...               32      389       2.13        17865
# 4                                             Mild Hybrid: 10 | Eléctrico: 12 | GNC: 12 | Híbrido: 105 | Híbrido/Nafta: 269                0        0       0.00        18254
# 5                                         Semiautomática: 1 | Automática secuencial: 123 | Manual: 5834 | Automática: 12281                1       15       0.08        18239
# 6                                 T270 1.3T: 1 | Nafta / Electrico: 1 | 1.5turbo: 1 | 3.0 biturbo 440cv: 1 | 2.5 Híbrido: 1              159       38       0.21        18216
# 7                                                                                                                SUV: 18254                0        0       0.00        18254
# 8                                                                                                        No: 960 | Sí: 3731                0    13563      74.30         4691
# 9                                                  54.000 km: 1 | 63.000 km: 1 | 83.000 km: 1 | 60.000 km: 1 | 40.000 km: 1             1362        0       0.00        18254
# 10  Land Rover Freelander 2.0 Hse 4 At: 1 | Hyundai Santa Fe: 1 | Mercedes-Benz Clase GLC 2.0 GLC300 4MATIC COUPE AMG-LI...             1168        0       0.00        18254
# 11                                                                                                     US$: 7096 | $: 11158                0        0       0.00        18254
# 12  EXCELENTE ESTADO (igual a 0km)Único dueñoListo para transferir y disfrutarLibre de deudasActualmente en garantía de ...            10662        0       0.00        18254
# 13                                                                    tienda: 4069 | particular: 5676 | concesionaria: 8509                0        0       0.00        18254
#
#     unique  unique_%
# 0       47      0.26
# 1      137      0.75
# 2     2072     11.35
# 3       70      0.38
# 4        8      0.04
# 5        4      0.02
# 6      271      1.48
# 7        1      0.01
# 8        2      0.01
# 9     2175     11.92
# 10    2220     12.16
# 11       2      0.01
# 12   12142     66.52
# 13       3      0.02

# %% [markdown]
# <h3 style="background-color: #343a40; color: #ffffff; display: inline-block; padding: 6px 10px; border-radius: 6px;">
# Initial Graphics Analysis
# </h3>

# %%
missing_table = eda.plot_missing_values(dataset)
currency_counts = eda.plot_currency_counts(dataset)
eda.plot_price_distribution_by_currency(dataset)
eda.plot_raw_numeric_distributions(dataset)
eda.plot_preliminary_outliers(dataset)

# %% [markdown]
# En las distribuciones raw se observan algunos valores claramente atípicos que afectan la forma de los gráficos. Por ejemplo, en `Año` aparece un valor imposible y en `Puertas` hay registros con cantidades extremadamente altas. Estos valores hacen que el eje del histograma se estire mucho y que la mayor parte de las observaciones reales quede comprimida en una sola zona.
#
# Por eso, para visualizar mejor las distribuciones, se filtraron los valores extremos solo al momento de graficar, usando percentiles. Esto no implica eliminar datos todavía, sino simplemente evitar que unos pocos outliers deformen el gráfico. La limpieza o corrección definitiva de estos valores se realizará más adelante durante el preprocesamiento.

# %%
print("=== Chequeo de valores atípicos simples ===")
print(f"Año máximo: {dataset['Año'].max()}")
print(f"Cantidad de años mayores a 2026: {(dataset['Año'] > 2026).sum()}")
print()
print(f"Cantidad máxima de puertas: {dataset['Puertas'].max()}")
print(f"Cantidad de observaciones con más de 7 puertas: {(dataset['Puertas'] > 7).sum()}")
# Out:
# === Chequeo de valores atípicos simples ===
# Año máximo: 436694.0
# Cantidad de años mayores a 2026: 1
#
# Cantidad máxima de puertas: 60252.0
# Cantidad de observaciones con más de 7 puertas: 4

# %% [markdown]
# Con este chequeo se detectan valores incoherentes en dos variables. En `Año` aparece una observación con valor `436694`, claramente mayor al año actual, por lo que se trata de un error de carga. Además, en `Puertas` se observa un valor máximo de `60252`, con 4 observaciones que tienen más de 7 puertas, lo cual tampoco es razonable para este tipo de vehículos.
#
# Como estos casos son pocos y corresponden a valores no interpretables, se podrian eliminar directamente en el preprocesamiento
